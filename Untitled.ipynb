# %% [markdown]
# # TOPIC : Movie Recommendation System

# %% [markdown]
# # Importing library

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# # Importing dataset

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')
credits = pd.read_csv('tmdb_5000_credits.csv')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies.shape
# Out:
# (4803, 20)

# %%
movies.info() #info in dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies = movies.merge(credits,on='title')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %% [markdown]
# # Data Visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

top_10 = movies[['title', 'vote_average']].sort_values(by='vote_average', ascending=False).head(10)

plt.figure(figsize=(12, 6))
sns.barplot(x='vote_average', y='title', data=top_10, palette='viridis')
plt.title('Top 10 Movies')
plt.xlabel('Vote Average')
plt.ylabel('Movie Title')
plt.show()
# Out:
# /var/folders/vp/cyv96clj695fqxxvdhl8dsrc0000gn/T/ipykernel_15006/2335108725.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='vote_average', y='title', data=top_10, palette='viridis')

# %%
movies.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.809000e+03    4809.000000  4809.000000  4.809000e+03  4807.000000
# mean   2.902780e+07   57120.571429    21.491664  8.227511e+07   106.882255
# std    4.070473e+07   88653.369849    31.803366  1.628379e+08    22.602535
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.800000e+05    9012.000000     4.667230  0.000000e+00    94.000000
# 50%    1.500000e+07   14624.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58595.000000    28.350529  9.291317e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count       movie_id
# count   4809.000000   4809.000000    4809.000000
# mean       6.092514    690.331670   57120.571429
# std        1.193989   1234.187111   88653.369849
# min        0.000000      0.000000       5.000000
# ...

# %%
movies.dtypes #datatypes in dataset
# Out:
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title                    object
# vote_average            float64
# vote_count                int64
# movie_id                  int64
# cast                     object
# crew                     object
# dtype: object

# %%
import pandas as pd
import ast
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt

# Parse the JSON-like strings and extract genre names
movies['genres'] = movies['genres'].apply(lambda x: [i['name'] for i in ast.literal_eval(x)])

# Flatten the list of genres
all_genres = [genre for sublist in movies['genres'] for genre in sublist]

# Count genre occurrences
genre_count = Counter(all_genres)

# Create DataFrame for plotting
genre_df = pd.DataFrame(genre_count.items(), columns=['Genre', 'Count']).sort_values(by='Count', ascending=False)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Count', y='Genre', data=genre_df, palette='coolwarm')
plt.title('Distribution of Movie Genres')
plt.xlabel('Number of Movies')
plt.ylabel('Genre')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/vp/cyv96clj695fqxxvdhl8dsrc0000gn/T/ipykernel_15006/570113014.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Count', y='Genre', data=genre_df, palette='coolwarm')

# %%
plt.figure(figsize=(8, 5))
sns.lineplot(x='budget', y='revenue', data=movies, alpha=0.6)
plt.title('Budget vs Revenue')
plt.xlabel('Budget (in million USD)')
plt.ylabel('Revenue (in million USD)')
plt.show()

# %%
movies = movies[['movie_id','title','overview','genres','keywords','cast','crew']]
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
import ast

def convert(text):
    if isinstance(text, list):
        return text
    try:
        L = []
        for i in ast.literal_eval(text):
            L.append(i['name'])
        return L
    except:
        return []

# %%
movies.dropna(inplace=True)
movies['genres'] = movies['genres'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies['keywords'] = movies['keywords'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
import ast
ast.literal_eval('[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]')
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
def convert3(text):
    L = []
    counter = 0
    for i in ast.literal_eval(text):
        if counter < 3:
            L.append(i['name'])
        counter+=1
    return L

# %%
movies['cast'] = movies['cast'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies['cast'] = movies['cast'].apply(lambda x:x[0:3])

# %%
def fetch_director(text):
    L = []
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
            L.append(i['name'])
    return L

# %%
movies['crew'] = movies['crew'].apply(fetch_director)    

#movies['overview'] = movies['overview'].apply(lambda x:x.split())
movies.sample(5)
# Out:
#       movie_id                             title  \
# 4680    194588  Short Cut to Nirvana: Kumbh Mela
# 1597      9918                        Glory Road
# 321      77953                      The Campaign
# 3100     12779                        Swept Away
# 2360      2575              The Tailor of Panama
#
#                                                overview             genres  \
# 4680  Every 12 years over 70 million pilgrims gather...                 []
# 1597  In 1966, Texas Western coach Don Haskins led t...            [Drama]
# 321   Two rival politicians compete to win an electi...           [Comedy]
# 3100  Stranded and alone on a desert island during a...  [Comedy, Romance]
# 2360  A British spy is banished to Panama after havi...  [Drama, Thriller]
#
#                                                keywords  \
# 4680                                                 []
# 1597  [basketball, racial segregation, teachers and ...
# ...

# %%
def collapse(L):
    L1 = []
    for i in L:
        L1.append(i.replace(" ",""))
    return L1

# %%
movies['cast'] = movies['cast'].apply(collapse)
movies['crew'] = movies['crew'].apply(collapse)
movies['genres'] = movies['genres'].apply(collapse)
movies['keywords'] = movies['keywords'].apply(collapse)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
# ...

# %%
movies['overview'] = movies['overview'].apply(lambda x:x.split())

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
new = movies.drop(columns=['overview','genres','keywords','cast','crew'])

# %%
new['tags'] = new['tags'].apply(lambda x: " ".join(x))
new.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
import pandas as pd

# Load the ratings file
ratings = pd.read_csv('u.data', sep='\t', names=['user_id', 'movie_id', 'rating', 'timestamp'])

print(ratings.head())
# Out:
#    user_id  movie_id  rating  timestamp
# 0      196       242       3  881250949
# 1      186       302       3  891717742
# 2       22       377       1  878887116
# 3      244        51       2  880606923
# 4      166       346       1  886397596

# %%
movies = pd.read_csv('u.item', sep='|', encoding='latin-1', header=None)
movies = movies[[0, 1]]
movies.columns = ['movie_id', 'title']

# Merge with ratings
merged = ratings.merge(movies, on='movie_id')
print(merged.head())
# Out:
#    user_id  movie_id  rating  timestamp                       title
# 0      196       242       3  881250949                Kolya (1996)
# 1      186       302       3  891717742    L.A. Confidential (1997)
# 2       22       377       1  878887116         Heavyweights (1994)
# 3      244        51       2  880606923  Legends of the Fall (1994)
# 4      166       346       1  886397596         Jackie Brown (1997)

# %%
import pandas as pd

# Load MovieLens ratings and movie info
ratings = pd.read_csv("u.data", sep="\t", names=["user_id", "movie_id", "rating", "timestamp"])
movies = pd.read_csv("u.item", sep="|", encoding="latin-1", header=None)
movies = movies[[0, 1]]  # movie_id and title only
movies.columns = ["movie_id", "title"]

# %%
# Remove year from title if present (e.g. "Toy Story (1995)" -> "Toy Story")
movies["clean_title"] = movies["title"].str.replace(r"\s\(\d{4}\)", "", regex=True)

# %%
tmdb_movies = pd.read_csv("tmdb_5000_movies.csv")  # from TMDB dataset
tmdb_movies["clean_title"] = tmdb_movies["title"].str.lower()

# %%
# Convert MovieLens titles to lowercase for matching
movies["clean_title"] = movies["clean_title"].str.lower()

# Merge MovieLens metadata with TMDB on cleaned titles
merged_movies = movies.merge(tmdb_movies, on="clean_title", how="inner")

# Now join with ratings
final_data = ratings.merge(merged_movies, on="movie_id")

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Load MovieLens ratings
ratings = pd.read_csv("u.data", sep="\t", names=["user_id", "movie_id", "rating", "timestamp"])

# Load MovieLens movie titles
movies = pd.read_csv("u.item", sep="|", encoding="latin-1", header=None, usecols=[0, 1])
movies.columns = ["movie_id", "title"]
movies["clean_title"] = movies["title"].str.replace(r"\s\(\d{4}\)", "", regex=True).str.lower()

# Load TMDB data
tmdb = pd.read_csv("tmdb_5000_movies.csv")
tmdb["clean_title"] = tmdb["title"].str.lower()

# Merge datasets
merged_movies = movies.merge(tmdb, on="clean_title", how="inner")
data = ratings.merge(merged_movies, on="movie_id")

# Create binary target variable
data["liked"] = data["rating"].apply(lambda x: 1 if x >= 4 else 0)

# Select features
features = data[["popularity", "vote_average", "vote_count"]]
target = data["liked"]

# Fill missing values
features = features.fillna(0)

# Scale features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(features_scaled, target, test_size=0.2, random_state=42)

# Train Logistic Regression
model = LogisticRegression()
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Evaluation
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[1729 2233]
#  [1116 4175]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.61      0.44      0.51      3962
#            1       0.65      0.79      0.71      5291
#
#     accuracy                           0.64      9253
#    macro avg       0.63      0.61      0.61      9253
# weighted avg       0.63      0.64      0.63      9253
#
# Accuracy: 0.6380633308116287

# %%
def recommend_movies(model, scaler, movie_data, top_n=10):
    # Filter only required features
    features = movie_data[["popularity", "vote_average", "vote_count"]].fillna(0)
    
    # Scale the features
    features_scaled = scaler.transform(features)
    
    # Predict whether the movie is liked (1) or not (0)
    predictions = model.predict(features_scaled)
    
    # Add predictions back to the movie data
    movie_data = movie_data.copy()
    movie_data["predicted_like"] = predictions
    
    # Filter only liked movies and return top_n by popularity
    recommended = movie_data[movie_data["predicted_like"] == 1]
    recommended = recommended.sort_values(by="popularity", ascending=False).head(top_n)
    
    return recommended[["original_title", "popularity", "vote_average"]]

# %%
recommended_movies = recommend_movies(model, scaler, merged_movies)
print("Top Recommended Movies Based on Logistic Regression:")
print(recommended_movies)
# Out:
# Top Recommended Movies Based on Logistic Regression:
#                       original_title  popularity  vote_average
# 30                      Forrest Gump  138.133331           8.2
# 159  One Flew Over the Cuckoo's Nest  127.525581           8.2
# 23                         Star Wars  126.393695           8.1
# 26                      Pulp Fiction  121.463076           8.3
# 140                 Schindler's List  104.469351           8.3
# 107                     Men in Black  104.121555           6.9
# 39        Terminator 2: Judgment Day  101.741550           7.7
# 181                       Cinderella  101.187052           6.7
# 138                          Titanic  100.025899           7.5
# 71                             Alien   94.184658           7.9

# %%
merged_movies['liked'] = (merged_movies['vote_average'] > 6.0).astype(int)

# %%
from sklearn.linear_model import LogisticRegression

# Train-test split (adjust as per your code)
X = merged_movies[["popularity", "vote_average"]]
y = merged_movies["liked"]

# Standardize features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train the model
log_reg_model = LogisticRegression()
log_reg_model.fit(X_scaled, y)
# Out:
# LogisticRegression()

# %%
import joblib

# Save model
joblib.dump(log_reg_model, "logistic_model.pkl")

# Save scaler
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
merged_movies.to_csv("processed_movies.csv", index=False)
